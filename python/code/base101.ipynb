# %%
x = 10
print('My family will come at %d P.M' %x)
# Out:
# My family will come at 10 P.M

# %%
mylist = [1,2,3]
print("A list: %s" % mylist)
# Out:
# A list: [1, 2, 3]

# %%
astring = "Hello world!"
print(astring.index("o"))
# Out:
# 4

# %%
astring = "Hello world!"
print(astring.count("l"))
# Out:
# 3

# %%
astring = "Hello_world!"
print(astring[3:7:2])
# Out:
# l_

# %%
astring = "Hello world!"
print(astring[::-1])
# Out:
# !dlrow olleH

# %%
astring = "Hello world!"
print(astring.upper())
print(astring.lower())
# Out:
# HELLO WORLD!
# hello world!

# %%
astring = "Hello world!"
print(astring.startswith("Hello"))
print(astring.endswith("asdfasdfasdf"))
# Out:
# True
# False

# %%
astring = "Hello world!"
afewwords = astring.split(" ")

# %%
afewwords
# Out:
# ['Hello', 'world!']

# %%
# Prints out 0,1,2,3,4

count = 0
while True:
    print(count)
    count += 1
    if count >= 5:
        break

# Prints out only odd numbers - 1,3,5,7,9
for x in range(10):
    # Check if x is even
    if x % 2 == 0:
        continue
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 1
# 3
# 5
# 7
# 9

# %%
class MyClass:
    variable = "blah"

    def function(self):
        print("This is a message inside the class.")

myobjectx = MyClass()

# %%
myobjectx.variable
# Out:
# 'blah'

# %%
myobjectx.function()
# Out:
# This is a message inside the class.

# %% [markdown]
# The __init__() function, is a special function that is called when the class is being initiated. It's used for assigning values in a class.

# %%
class NumberHolder:

   def __init__(self, number):
       self.number = number

# %%
phonebook = {"John" : 44,"Jack" : 33,"Jill" : 22}

for name, number in phonebook.items():
    print("Code number of %s is %d" % (name, number))
# Out:
# Code number of John is 44
# Code number of Jack is 33
# Code number of Jill is 22

# %%
phonebook.pop("John")
print(phonebook)
# Out:
# {'Jack': 33, 'Jill': 22}

# %% [markdown]
# When importing a module, a .pyc file is created. This is a compiled Python file. Python compiles files into Python bytecode so that it won't have to parse the files each time modules are loaded. If a .pyc file exists, it gets loaded instead of the .py file. This process is transparent to the user.  You can use the environment variable PYTHONPATH to specify additional directories to look for modules like this:

# %%
#PYTHONPATH=/foo/pythongame.py
import sys
sys.path.append("/foo")

# %% [markdown]
# We can look for which functions are implemented in each module by using the dir function:

# %%
import matplotlib

# %%
dir(matplotlib)
# Out:
# ['ExecutableNotFoundError',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  '_ExecInfo',
#  '_VersionInfo',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_add_data_doc',
#  '_afm',
#  '_api',
#  '_blocking_input',
#  '_c_internal_utils',
#  '_check_versions',
#  '_cm',
#  '_cm_listed',
#  '_color_data',
#  '_constrained_layout',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_docstring',
#  '_ensure_handler',
#  '_enums',
#  '_fontconfig_pattern',
#  '_get_config_or_cache_dir',
#  '_get_executable_info',
#  '_get_ssl_context',
#  '_get_version',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_image',
#  '_init_tests',
#  '_label_from_arg',
#  '_layoutgrid',
#  '_log',
#  '_logged_cached',
#  '_mathtext',
#  '_mathtext_data',
# ...

# %%
help(matplotlib.pyplot)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     an implicit,  MATLAB-like, way of plotting.  It also opens figures on your
#     screen, and acts as the figure GUI manager.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The explicit object-oriented API is recommended for complex plots, though
#     pyplot is still usually used to create the figure and often the axes in the
#     figure. See `.pyplot.figure`, `.pyplot.subplots`, and
#     `.pyplot.subplot_mosaic` to create figures, and
#     :doc:`Axes API </api/axes_api>` for the plotting methods on an Axes::
#
#         import numpy as np
# ...

# %% [markdown]
# If we create a directory called foo, which marks the package name, we can then create a module inside that package called bar. Then we add the __init__.py file inside the foo directory.

# %%
# import foo.bar

# %%
dict = {"country": ["Brazil", "Russia", "India", "China", "South Africa"],
       "capital": ["Brasilia", "Moscow", "New Dehli", "Beijing", "Pretoria"],
       "area": [8.516, 17.10, 3.286, 9.597, 1.221],
       "population": [200.4, 143.5, 1252, 1357, 52.98] }

import pandas as pd
brics = pd.DataFrame(dict)
print(brics)
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Dehli   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
# Set the index for brics
brics.index = ["BR", "RU", "IN", "CH", "SA"]

# Print out brics with new index values
print(brics)
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Dehli   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
import pandas as pd
#cars = pd.read_csv('cars.csv', index_col = 0)
cars = brics
# Print out first 4 observations
print(cars[0:4])
# Out:
#    country    capital    area  population
# BR  Brazil   Brasilia   8.516       200.4
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Dehli   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
print(cars.iloc[1])
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
print(cars.loc['BR'])
# Out:
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object

# %%
# Create 2 new lists height and weight
height = [1.87,  1.87, 1.82, 1.91, 1.90, 1.85]
weight = [81.65, 97.52, 95.25, 92.98, 86.18, 88.45]

# Import the numpy package as np
import numpy as np

# Create 2 numpy arrays from height and weight
np_height = np.array(height)
np_weight = np.array(weight)

# %%
# Calculate bmi
bmi = np_weight / np_height ** 2

# Print the result
print(bmi)
# Out:
# [23.34925219 27.88755755 28.75558507 25.48723993 23.87257618 25.84368152]

# %%
# Print only those observations above 23
bmi[bmi > 24]
# Out:
# array([27.88755755, 28.75558507, 25.48723993, 25.84368152])

# %%
  a = [5, 1, 4, 3]
  print(sorted(a))
# Out:
# [1, 3, 4, 5]

# %%
  strs = ['aa', 'BB', 'zz', 'CC']
  print(sorted(strs))  ## ['BB', 'CC', 'aa', 'zz'] (case sensitive)
  print(sorted(strs, reverse=True))   ## ['zz', 'aa', 'CC', 'BB']
# Out:
# ['BB', 'CC', 'aa', 'zz']
# ['zz', 'aa', 'CC', 'BB']

# %%
  strs = ['ccc', 'aaaa', 'd', 'bb']
  print(sorted(strs, key=len))  ## ['d', 'bb', 'ccc', 'aaaa']
# Out:
# ['d', 'bb', 'ccc', 'aaaa']

# %% [markdown]
#  "str.lower" as the key function is a way to force the sorting to treat uppercase and lowercase the same:

# %%
  print(sorted(strs, key=str.lower))  ## ['aa', 'BB', 'CC', 'zz']
# Out:
# ['aaaa', 'bb', 'ccc', 'd']

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()
